# %%
# !pip install llama-index
# !pip install llama-index-core llama-index-readers-file llama-index-llms-ollama llama-index-embeddings-huggingface
# !pip install llama_index==0.9.24
# Out:
# Requirement already satisfied: llama-index in ./v_env/lib/python3.12/site-packages (0.9.24)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in ./v_env/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in ./v_env/lib/python3.12/site-packages (from llama-index) (3.10.3)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.2 in ./v_env/lib/python3.12/site-packages (from llama-index) (4.12.3)
# Requirement already satisfied: dataclasses-json in ./v_env/lib/python3.12/site-packages (from llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in ./v_env/lib/python3.12/site-packages (from llama-index) (1.2.14)
# Requirement already satisfied: fsspec>=2023.5.0 in ./v_env/lib/python3.12/site-packages (from llama-index) (2024.6.1)
# Requirement already satisfied: httpx in ./v_env/lib/python3.12/site-packages (from llama-index) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in ./v_env/lib/python3.12/site-packages (from llama-index) (1.6.0)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in ./v_env/lib/python3.12/site-packages (from llama-index) (3.8.2)
# Requirement already satisfied: numpy in ./v_env/lib/python3.12/site-packages (from llama-index) (1.26.4)
# Requirement already satisfied: openai>=1.1.0 in ./v_env/lib/python3.12/site-packages (from llama-index) (1.40.6)
# Requirement already satisfied: pandas in ./v_env/lib/python3.12/site-packages (from llama-index) (2.2.2)
# Requirement already satisfied: requests>=2.31.0 in ./v_env/lib/python3.12/site-packages (from llama-index) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in ./v_env/lib/python3.12/site-packages (from llama-index) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in ./v_env/lib/python3.12/site-packages (from llama-index) (0.7.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in ./v_env/lib/python3.12/site-packages (from llama-index) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in ./v_env/lib/python3.12/site-packages (from llama-index) (0.9.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./v_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index) (2.3.5)
# Requirement already satisfied: aiosignal>=1.1.2 in ./v_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in ./v_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./v_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./v_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./v_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index) (1.9.4)
# Requirement already satisfied: soupsieve>1.2 in ./v_env/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.12.2->llama-index) (2.6)
# Requirement already satisfied: wrapt<2,>=1.10 in ./v_env/lib/python3.12/site-packages (from deprecated>=1.2.9.3->llama-index) (1.16.0)
# Requirement already satisfied: click in ./v_env/lib/python3.12/site-packages (from nltk<4.0.0,>=3.8.1->llama-index) (8.1.7)
# Requirement already satisfied: joblib in ./v_env/lib/python3.12/site-packages (from nltk<4.0.0,>=3.8.1->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in ./v_env/lib/python3.12/site-packages (from nltk<4.0.0,>=3.8.1->llama-index) (2024.7.24)
# Requirement already satisfied: tqdm in ./v_env/lib/python3.12/site-packages (from nltk<4.0.0,>=3.8.1->llama-index) (4.66.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./v_env/lib/python3.12/site-packages (from openai>=1.1.0->llama-index) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./v_env/lib/python3.12/site-packages (from openai>=1.1.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./v_env/lib/python3.12/site-packages (from openai>=1.1.0->llama-index) (0.5.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./v_env/lib/python3.12/site-packages (from openai>=1.1.0->llama-index) (2.8.2)
# Requirement already satisfied: sniffio in ./v_env/lib/python3.12/site-packages (from openai>=1.1.0->llama-index) (1.3.1)
# Requirement already satisfied: certifi in ./v_env/lib/python3.12/site-packages (from httpx->llama-index) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in ./v_env/lib/python3.12/site-packages (from httpx->llama-index) (1.0.5)
# Requirement already satisfied: idna in ./v_env/lib/python3.12/site-packages (from httpx->llama-index) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in ./v_env/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./v_env/lib/python3.12/site-packages (from requests>=2.31.0->llama-index) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./v_env/lib/python3.12/site-packages (from requests>=2.31.0->llama-index) (2.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in ./v_env/lib/python3.12/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./v_env/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./v_env/lib/python3.12/site-packages (from dataclasses-json->llama-index) (3.21.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./v_env/lib/python3.12/site-packages (from pandas->llama-index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./v_env/lib/python3.12/site-packages (from pandas->llama-index) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./v_env/lib/python3.12/site-packages (from pandas->llama-index) (2024.1)
# Requirement already satisfied: packaging>=17.0 in ./v_env/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index) (24.1)
# Requirement already satisfied: annotated-types>=0.4.0 in ./v_env/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in ./v_env/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama-index) (2.20.1)
# Requirement already satisfied: six>=1.5 in ./v_env/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->llama-index) (1.16.0)
# Requirement already satisfied: llama-index-core in ./v_env/lib/python3.12/site-packages (0.10.65)
# Requirement already satisfied: llama-index-readers-file in ./v_env/lib/python3.12/site-packages (0.1.33)
# Requirement already satisfied: llama-index-llms-ollama in ./v_env/lib/python3.12/site-packages (0.2.2)
# Requirement already satisfied: llama-index-embeddings-huggingface in ./v_env/lib/python3.12/site-packages (0.2.3)
# Requirement already satisfied: PyYAML>=6.0.1 in ./v_env/lib/python3.12/site-packages (from llama-index-core) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in ./v_env/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in ./v_env/lib/python3.12/site-packages (from llama-index-core) (3.10.3)
# Requirement already satisfied: dataclasses-json in ./v_env/lib/python3.12/site-packages (from llama-index-core) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in ./v_env/lib/python3.12/site-packages (from llama-index-core) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in ./v_env/lib/python3.12/site-packages (from llama-index-core) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in ./v_env/lib/python3.12/site-packages (from llama-index-core) (2024.6.1)
# Requirement already satisfied: httpx in ./v_env/lib/python3.12/site-packages (from llama-index-core) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in ./v_env/lib/python3.12/site-packages (from llama-index-core) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in ./v_env/lib/python3.12/site-packages (from llama-index-core) (3.3)
# Requirement already satisfied: nltk>=3.8.2 in ./v_env/lib/python3.12/site-packages (from llama-index-core) (3.8.2)
# Requirement already satisfied: numpy<2.0.0 in ./v_env/lib/python3.12/site-packages (from llama-index-core) (1.26.4)
# Requirement already satisfied: openai>=1.1.0 in ./v_env/lib/python3.12/site-packages (from llama-index-core) (1.40.6)
# Requirement already satisfied: pandas in ./v_env/lib/python3.12/site-packages (from llama-index-core) (2.2.2)
# Requirement already satisfied: pillow>=9.0.0 in ./v_env/lib/python3.12/site-packages (from llama-index-core) (10.4.0)
# Requirement already satisfied: requests>=2.31.0 in ./v_env/lib/python3.12/site-packages (from llama-index-core) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in ./v_env/lib/python3.12/site-packages (from llama-index-core) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in ./v_env/lib/python3.12/site-packages (from llama-index-core) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in ./v_env/lib/python3.12/site-packages (from llama-index-core) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in ./v_env/lib/python3.12/site-packages (from llama-index-core) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in ./v_env/lib/python3.12/site-packages (from llama-index-core) (0.9.0)
# Requirement already satisfied: wrapt in ./v_env/lib/python3.12/site-packages (from llama-index-core) (1.16.0)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in ./v_env/lib/python3.12/site-packages (from llama-index-readers-file) (4.12.3)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in ./v_env/lib/python3.12/site-packages (from llama-index-readers-file) (4.3.1)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in ./v_env/lib/python3.12/site-packages (from llama-index-readers-file) (0.0.26)
# Requirement already satisfied: ollama>=0.3.0 in ./v_env/lib/python3.12/site-packages (from llama-index-llms-ollama) (0.3.1)
# Requirement already satisfied: huggingface-hub>=0.19.0 in ./v_env/lib/python3.12/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.24.5)
# Requirement already satisfied: sentence-transformers>=2.6.1 in ./v_env/lib/python3.12/site-packages (from llama-index-embeddings-huggingface) (3.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./v_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (2.3.5)
# Requirement already satisfied: aiosignal>=1.1.2 in ./v_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in ./v_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./v_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./v_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./v_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.9.4)
# Requirement already satisfied: soupsieve>1.2 in ./v_env/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file) (2.6)
# Requirement already satisfied: filelock in ./v_env/lib/python3.12/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.15.4)
# Requirement already satisfied: packaging>=20.9 in ./v_env/lib/python3.12/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (24.1)
# Requirement already satisfied: minijinja>=1.0 in ./v_env/lib/python3.12/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.0.1)
# Requirement already satisfied: click in ./v_env/lib/python3.12/site-packages (from nltk>=3.8.2->llama-index-core) (8.1.7)
# Requirement already satisfied: joblib in ./v_env/lib/python3.12/site-packages (from nltk>=3.8.2->llama-index-core) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in ./v_env/lib/python3.12/site-packages (from nltk>=3.8.2->llama-index-core) (2024.7.24)
# Requirement already satisfied: anyio in ./v_env/lib/python3.12/site-packages (from httpx->llama-index-core) (4.4.0)
# Requirement already satisfied: certifi in ./v_env/lib/python3.12/site-packages (from httpx->llama-index-core) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in ./v_env/lib/python3.12/site-packages (from httpx->llama-index-core) (1.0.5)
# Requirement already satisfied: idna in ./v_env/lib/python3.12/site-packages (from httpx->llama-index-core) (3.7)
# Requirement already satisfied: sniffio in ./v_env/lib/python3.12/site-packages (from httpx->llama-index-core) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in ./v_env/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core) (0.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./v_env/lib/python3.12/site-packages (from openai>=1.1.0->llama-index-core) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./v_env/lib/python3.12/site-packages (from openai>=1.1.0->llama-index-core) (0.5.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./v_env/lib/python3.12/site-packages (from openai>=1.1.0->llama-index-core) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./v_env/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./v_env/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core) (2.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in ./v_env/lib/python3.12/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (4.44.0)
# Requirement already satisfied: torch>=1.11.0 in ./v_env/lib/python3.12/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.4.0)
# Requirement already satisfied: scikit-learn in ./v_env/lib/python3.12/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.5.1)
# Requirement already satisfied: scipy in ./v_env/lib/python3.12/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.14.0)
# Requirement already satisfied: greenlet!=0.4.17 in ./v_env/lib/python3.12/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./v_env/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./v_env/lib/python3.12/site-packages (from dataclasses-json->llama-index-core) (3.21.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./v_env/lib/python3.12/site-packages (from pandas->llama-index-core) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./v_env/lib/python3.12/site-packages (from pandas->llama-index-core) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./v_env/lib/python3.12/site-packages (from pandas->llama-index-core) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in ./v_env/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama-index-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in ./v_env/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama-index-core) (2.20.1)
# Requirement already satisfied: six>=1.5 in ./v_env/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core) (1.16.0)
# Requirement already satisfied: sympy in ./v_env/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.13.2)
# Requirement already satisfied: jinja2 in ./v_env/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.1.4)
# Requirement already satisfied: setuptools in ./v_env/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (72.2.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./v_env/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./v_env/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./v_env/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./v_env/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./v_env/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./v_env/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./v_env/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./v_env/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./v_env/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in ./v_env/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./v_env/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in ./v_env/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./v_env/lib/python3.12/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (12.6.20)
# Requirement already satisfied: safetensors>=0.4.1 in ./v_env/lib/python3.12/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in ./v_env/lib/python3.12/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.19.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./v_env/lib/python3.12/site-packages (from scikit-learn->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./v_env/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./v_env/lib/python3.12/site-packages (from sympy->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.3.0)
# Requirement already satisfied: llama_index==0.9.24 in ./v_env/lib/python3.12/site-packages (0.9.24)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in ./v_env/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama_index==0.9.24) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in ./v_env/lib/python3.12/site-packages (from llama_index==0.9.24) (3.10.3)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.2 in ./v_env/lib/python3.12/site-packages (from llama_index==0.9.24) (4.12.3)
# Requirement already satisfied: dataclasses-json in ./v_env/lib/python3.12/site-packages (from llama_index==0.9.24) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in ./v_env/lib/python3.12/site-packages (from llama_index==0.9.24) (1.2.14)
# Requirement already satisfied: fsspec>=2023.5.0 in ./v_env/lib/python3.12/site-packages (from llama_index==0.9.24) (2024.6.1)
# Requirement already satisfied: httpx in ./v_env/lib/python3.12/site-packages (from llama_index==0.9.24) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in ./v_env/lib/python3.12/site-packages (from llama_index==0.9.24) (1.6.0)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in ./v_env/lib/python3.12/site-packages (from llama_index==0.9.24) (3.8.2)
# Requirement already satisfied: numpy in ./v_env/lib/python3.12/site-packages (from llama_index==0.9.24) (1.26.4)
# Requirement already satisfied: openai>=1.1.0 in ./v_env/lib/python3.12/site-packages (from llama_index==0.9.24) (1.40.6)
# Requirement already satisfied: pandas in ./v_env/lib/python3.12/site-packages (from llama_index==0.9.24) (2.2.2)
# Requirement already satisfied: requests>=2.31.0 in ./v_env/lib/python3.12/site-packages (from llama_index==0.9.24) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in ./v_env/lib/python3.12/site-packages (from llama_index==0.9.24) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in ./v_env/lib/python3.12/site-packages (from llama_index==0.9.24) (0.7.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in ./v_env/lib/python3.12/site-packages (from llama_index==0.9.24) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in ./v_env/lib/python3.12/site-packages (from llama_index==0.9.24) (0.9.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./v_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama_index==0.9.24) (2.3.5)
# Requirement already satisfied: aiosignal>=1.1.2 in ./v_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama_index==0.9.24) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in ./v_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama_index==0.9.24) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./v_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama_index==0.9.24) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./v_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama_index==0.9.24) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./v_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama_index==0.9.24) (1.9.4)
# Requirement already satisfied: soupsieve>1.2 in ./v_env/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.12.2->llama_index==0.9.24) (2.6)
# Requirement already satisfied: wrapt<2,>=1.10 in ./v_env/lib/python3.12/site-packages (from deprecated>=1.2.9.3->llama_index==0.9.24) (1.16.0)
# Requirement already satisfied: click in ./v_env/lib/python3.12/site-packages (from nltk<4.0.0,>=3.8.1->llama_index==0.9.24) (8.1.7)
# Requirement already satisfied: joblib in ./v_env/lib/python3.12/site-packages (from nltk<4.0.0,>=3.8.1->llama_index==0.9.24) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in ./v_env/lib/python3.12/site-packages (from nltk<4.0.0,>=3.8.1->llama_index==0.9.24) (2024.7.24)
# Requirement already satisfied: tqdm in ./v_env/lib/python3.12/site-packages (from nltk<4.0.0,>=3.8.1->llama_index==0.9.24) (4.66.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./v_env/lib/python3.12/site-packages (from openai>=1.1.0->llama_index==0.9.24) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./v_env/lib/python3.12/site-packages (from openai>=1.1.0->llama_index==0.9.24) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./v_env/lib/python3.12/site-packages (from openai>=1.1.0->llama_index==0.9.24) (0.5.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./v_env/lib/python3.12/site-packages (from openai>=1.1.0->llama_index==0.9.24) (2.8.2)
# Requirement already satisfied: sniffio in ./v_env/lib/python3.12/site-packages (from openai>=1.1.0->llama_index==0.9.24) (1.3.1)
# Requirement already satisfied: certifi in ./v_env/lib/python3.12/site-packages (from httpx->llama_index==0.9.24) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in ./v_env/lib/python3.12/site-packages (from httpx->llama_index==0.9.24) (1.0.5)
# Requirement already satisfied: idna in ./v_env/lib/python3.12/site-packages (from httpx->llama_index==0.9.24) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in ./v_env/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama_index==0.9.24) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./v_env/lib/python3.12/site-packages (from requests>=2.31.0->llama_index==0.9.24) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./v_env/lib/python3.12/site-packages (from requests>=2.31.0->llama_index==0.9.24) (2.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in ./v_env/lib/python3.12/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama_index==0.9.24) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./v_env/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama_index==0.9.24) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./v_env/lib/python3.12/site-packages (from dataclasses-json->llama_index==0.9.24) (3.21.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./v_env/lib/python3.12/site-packages (from pandas->llama_index==0.9.24) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./v_env/lib/python3.12/site-packages (from pandas->llama_index==0.9.24) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./v_env/lib/python3.12/site-packages (from pandas->llama_index==0.9.24) (2024.1)
# Requirement already satisfied: packaging>=17.0 in ./v_env/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama_index==0.9.24) (24.1)
# Requirement already satisfied: annotated-types>=0.4.0 in ./v_env/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama_index==0.9.24) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in ./v_env/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama_index==0.9.24) (2.20.1)
# Requirement already satisfied: six>=1.5 in ./v_env/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->llama_index==0.9.24) (1.16.0)

# %%
# from llama_index.llms.ollama import Ollama

# llm = Ollama(model="llama2", request_timeout=600) #base_url = 'http://localhost:11434',

# response = llm.complete("Do you know about Claude-3?") ## stream_complete() for streaming response

# response
# print(response.text)

# %%
# Importing required modules
from pypdf import PdfReader
from llama_index.core import VectorStoreIndex, Document
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.core import Settings
from llama_index.llms.ollama import Ollama
# from llama_index import SimpleDirectoryReader

# Creating a pdf reader object
reader = PdfReader('faq.pdf')
# reader = SimpleDirectoryReader("/home/abhi/Documents/ChatBot/Llama2/data").load_data()

# Extracting text from all pages
all_text = ""
for page in reader.pages:
    all_text += page.extract_text() + "\n"

# Setting up the embedding model and LLM
Settings.embed_model = HuggingFaceEmbedding(
    model_name="BAAI/bge-small-en-v1.5"
)
Settings.llm = Ollama(model="llama2", request_timeout=600)

# Creating a Document object
doc = Document(text=all_text)

# Creating the VectorStoreIndex
index = VectorStoreIndex.from_documents([doc])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 3
#       1 # Importing required modules
#       2 from pypdf import PdfReader
# ----> 3 from llama_index.core import VectorStoreIndex, Document
#       4 from llama_index.embeddings.huggingface import HuggingFaceEmbedding
#       5 from llama_index.core import Settings
#
# File ~/Documents/ChatBot/Llama2/v_env/lib/python3.12/site-packages/llama_index/__init__.py:13
#      10 from typing import Callable, Optional
#      12 # import global eval handler
# ---> 13 from llama_index.callbacks.global_handlers import set_global_handler
#      14 from llama_index.data_structs.struct_type import IndexStructType
#      16 # embeddings
#
# File ~/Documents/ChatBot/Llama2/v_env/lib/python3.12/site-packages/llama_index/callbacks/__init__.py:7
#       5 from .open_inference_callback import OpenInferenceCallbackHandler
#       6 from .schema import CBEvent, CBEventType, EventPayload
# ----> 7 from .token_counting import TokenCountingHandler
#       8 from .utils import trace_method
#       9 from .wandb_callback import WandbCallbackHandler
#
# File ~/Documents/ChatBot/Llama2/v_env/lib/python3.12/site-packages/llama_index/callbacks/token_counting.py:6
#       4 from llama_index.callbacks.base_handler import BaseCallbackHandler
#       5 from llama_index.callbacks.schema import CBEventType, EventPayload
# ----> 6 from llama_index.utilities.token_counting import TokenCounter
#       7 from llama_index.utils import get_tokenizer
#      10 @dataclass
#      11 class TokenCountingEvent:
#
# File ~/Documents/ChatBot/Llama2/v_env/lib/python3.12/site-packages/llama_index/utilities/token_counting.py:6
#       1 # Modified from:
#       2 # https://github.com/nyno-ai/openai-token-counter
#       4 from typing import Any, Callable, Dict, List, Optional
# ----> 6 from llama_index.llms import ChatMessage, MessageRole
#       7 from llama_index.utils import get_tokenizer
#      10 class TokenCounter:
#
# File ~/Documents/ChatBot/Llama2/v_env/lib/python3.12/site-packages/llama_index/llms/__init__.py:3
#       1 from llama_index.llms.ai21 import AI21
#       2 from llama_index.llms.anthropic import Anthropic
# ----> 3 from llama_index.llms.anyscale import Anyscale
#       4 from llama_index.llms.azure_openai import AzureOpenAI
#       5 from llama_index.llms.bedrock import Bedrock
#
# File ~/Documents/ChatBot/Llama2/v_env/lib/python3.12/site-packages/llama_index/llms/anyscale.py:9
#       5 from llama_index.llms.anyscale_utils import (
#       6     anyscale_modelname_to_contextsize,
#       7 )
#       8 from llama_index.llms.generic_utils import get_from_param_or_env
# ----> 9 from llama_index.llms.openai import OpenAI
#      10 from llama_index.llms.types import ChatMessage, LLMMetadata
#      11 from llama_index.types import BaseOutputParser, PydanticProgramMode
#
# File ~/Documents/ChatBot/Llama2/v_env/lib/python3.12/site-packages/llama_index/llms/openai/__init__.py:1
# ----> 1 from llama_index.llms.openai.base import AsyncOpenAI, OpenAI, SyncOpenAI, Tokenizer
#       3 __all__ = ["OpenAI", "Tokenizer", "SyncOpenAI", "AsyncOpenAI"]
#
# File ~/Documents/ChatBot/Llama2/v_env/lib/python3.12/site-packages/llama_index/llms/openai/base.py:20
#      18 import httpx
#      19 import tiktoken
# ---> 20 from llama_index.core.base.llms.generic_utils import (
#      21     achat_to_completion_decorator,
#      22     acompletion_to_chat_decorator,
#      23     astream_chat_to_completion_decorator,
#      24     astream_completion_to_chat_decorator,
#      25     chat_to_completion_decorator,
#      26     completion_to_chat_decorator,
#      27     stream_chat_to_completion_decorator,
#      28     stream_completion_to_chat_decorator,
#      29 )
#      30 from llama_index.core.base.llms.types import (
#      31     ChatMessage,
#      32     ChatResponse,
#    (...)
#      39     MessageRole,
#      40 )
#      41 from llama_index.core.bridge.pydantic import Field, PrivateAttr
#
# File ~/Documents/ChatBot/Llama2/v_env/lib/python3.12/site-packages/llama_index/core/__init__.py:1
# ----> 1 from llama_index.core.base_multi_modal_retriever import MultiModalRetriever
#       2 from llama_index.core.base_query_engine import BaseQueryEngine
#       3 from llama_index.core.base_retriever import BaseRetriever
#
# File ~/Documents/ChatBot/Llama2/v_env/lib/python3.12/site-packages/llama_index/core/base_multi_modal_retriever.py:5
#       2 from abc import abstractmethod
#       3 from typing import List
# ----> 5 from llama_index.core.base_retriever import BaseRetriever
#       6 from llama_index.core.image_retriever import BaseImageRetriever
#       7 from llama_index.indices.query.schema import QueryType
#
# File ~/Documents/ChatBot/Llama2/v_env/lib/python3.12/site-packages/llama_index/core/base_retriever.py:7
#       5 from llama_index.callbacks.base import CallbackManager
#       6 from llama_index.callbacks.schema import CBEventType, EventPayload
# ----> 7 from llama_index.indices.query.schema import QueryBundle, QueryType
#       8 from llama_index.indices.service_context import ServiceContext
#       9 from llama_index.prompts.mixin import PromptDictType, PromptMixin, PromptMixinType
#
# File ~/Documents/ChatBot/Llama2/v_env/lib/python3.12/site-packages/llama_index/indices/__init__.py:4
#       1 """LlamaIndex data structures."""
#       3 # indices
# ----> 4 from llama_index.indices.composability.graph import ComposableGraph
#       5 from llama_index.indices.document_summary import (
#       6     DocumentSummaryIndex,
#       7     GPTDocumentSummaryIndex,
#       8 )
#       9 from llama_index.indices.document_summary.base import DocumentSummaryIndex
#
# File ~/Documents/ChatBot/Llama2/v_env/lib/python3.12/site-packages/llama_index/indices/composability/__init__.py:4
#       1 """This module contains all classes used for composing graphs over indices."""
# ----> 4 from llama_index.indices.composability.graph import ComposableGraph
#       6 __all__ = ["ComposableGraph"]
#
# File ~/Documents/ChatBot/Llama2/v_env/lib/python3.12/site-packages/llama_index/indices/composability/graph.py:5
#       1 """Composability graphs."""
#       3 from typing import Any, Dict, List, Optional, Sequence, Type, cast
# ----> 5 from llama_index.core import BaseQueryEngine
#       6 from llama_index.data_structs.data_structs import IndexStruct
#       7 from llama_index.indices.base import BaseIndex
#
# ImportError: cannot import name 'BaseQueryEngine' from partially initialized module 'llama_index.core' (most likely due to a circular import) (/home/abhi/Documents/ChatBot/Llama2/v_env/lib/python3.12/site-packages/llama_index/core/__init__.py)

# %%
retriever = index.as_retriever(similarity_top_k=2)

# Function to get response with LLM validation
def get_validated_response(question):
    # Retrieve relevant documents
    retrieved_nodes = retriever.retrieve(question)
    
    # Prepare context for LLM
    context = "\n".join([node.text for node in retrieved_nodes])
    
    # Prepare prompt for LLM
    prompt = f"""Given the following context and question, provide a accurate and concise answer. If the context doesn't contain enough information to answer the question confidently, state that clearly.

Context:
{context}

Question: {question}

Answer:"""

    # Use LLM to generate a validated response
    llm = Ollama(model="llama2", request_timeout=600, temperature=0.1)
    response = llm.complete(prompt)
    
    return response

# Example usage
# question = "i am a farmar, how can i apply for this scheme??"
# response = get_validated_response(question)
# print(response)

# %%
question = "i am a student, how can i apply for this scheme??"
response = get_validated_response(question)
print(response)
# Out:
# To apply for PMAY-U 2.0 as a farmer, you can follow these steps:
#
# 1. Check your eligibility: Before applying for the scheme, make sure you meet the eligibility criteria defined by the government. You can check the eligibility criteria on the official website of PMAY-U 2.0 or by contacting your state government's urban development department.
# 2. Register yourself: If you are eligible, register yourself on the online portal of PMAY-U 2.0. You can find the link to the portal on the official website of the scheme.
# 3. Fill the application form: Once you have registered yourself, fill the application form with all the required details. Make sure you provide accurate information and attach the necessary documents, such as your Adhaar card, bank account details, and land ownership documents.
# 4. Submit the application: After filling the application form, submit it online or through a Common Service Centre (CSC) near you.
# 5. Wait for the selection: The government will review your application and select beneficiaries based on the criteria defined in the scheme. If you are selected, you will receive an intimation from the government with further instructions.
#
# Note: The application process and eligibility criteria may vary depending on the state or union territory you are residing in. It is best to check the official website of PMAY-U 2.0 or contact your state government's urban development department for more information.
