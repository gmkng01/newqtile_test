# %%
# !pip install --upgrade pip
# # ! pip install haystack 
# !pip install haystack-ai
# !pip install farm-haystack[colab,inference]
# !pip3.10 uninstall pydantic urllib3
# !pip install farm-haystack[colab,preprocessing,elasticsearch,inference]
# !pip3.8 install -r requirements.txt
# Out:
# Requirement already satisfied: backports.tarfile in ./new_env3.8/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: chromadb in ./new_env3.8/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (0.5.5)
# Requirement already satisfied: datasets in ./new_env3.8/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (2.21.0)
# Requirement already satisfied: gradio in ./new_env3.8/lib/python3.8/site-packages (from -r requirements.txt (line 4)) (4.41.0)
# Requirement already satisfied: h2 in ./new_env3.8/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (4.1.0)
# Requirement already satisfied: httptools in ./new_env3.8/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (0.6.1)
# Requirement already satisfied: ipykernel in ./new_env3.8/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (6.29.5)
# Requirement already satisfied: jaraco.text in ./new_env3.8/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (4.0.0)
# Requirement already satisfied: langchain-community in ./new_env3.8/lib/python3.8/site-packages (from -r requirements.txt (line 9)) (0.2.12)
# Requirement already satisfied: ollama-haystack in ./new_env3.8/lib/python3.8/site-packages (from -r requirements.txt (line 10)) (0.0.7)
# Requirement already satisfied: ordered-set in ./new_env3.8/lib/python3.8/site-packages (from -r requirements.txt (line 11)) (4.1.0)
# Requirement already satisfied: pip-chill in ./new_env3.8/lib/python3.8/site-packages (from -r requirements.txt (line 12)) (1.0.3)
# Requirement already satisfied: pypdf in ./new_env3.8/lib/python3.8/site-packages (from -r requirements.txt (line 13)) (4.3.1)
# Requirement already satisfied: python-dotenv in ./new_env3.8/lib/python3.8/site-packages (from -r requirements.txt (line 14)) (1.0.1)
# Requirement already satisfied: pydantic in ./new_env3.8/lib/python3.8/site-packages (from -r requirements.txt (line 15)) (2.8.2)
# Requirement already satisfied: urllib3 in ./new_env3.8/lib/python3.8/site-packages (from -r requirements.txt (line 16)) (2.2.2)
# Requirement already satisfied: qdrant-haystack in ./new_env3.8/lib/python3.8/site-packages (from -r requirements.txt (line 17)) (4.1.2)
# Requirement already satisfied: sentence-transformers in ./new_env3.8/lib/python3.8/site-packages (from -r requirements.txt (line 18)) (3.0.1)
# Requirement already satisfied: tomli in ./new_env3.8/lib/python3.8/site-packages (from -r requirements.txt (line 19)) (2.0.1)
# Requirement already satisfied: uvloop in ./new_env3.8/lib/python3.8/site-packages (from -r requirements.txt (line 20)) (0.20.0)
# Requirement already satisfied: watchfiles in ./new_env3.8/lib/python3.8/site-packages (from -r requirements.txt (line 21)) (0.23.0)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in ./new_env3.8/lib/python3.8/site-packages (from chromadb->-r requirements.txt (line 2)) (0.7.6)
# Requirement already satisfied: grpcio>=1.58.0 in ./new_env3.8/lib/python3.8/site-packages (from chromadb->-r requirements.txt (line 2)) (1.65.5)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in ./new_env3.8/lib/python3.8/site-packages (from chromadb->-r requirements.txt (line 2)) (1.26.0)
# Requirement already satisfied: build>=1.0.3 in ./new_env3.8/lib/python3.8/site-packages (from chromadb->-r requirements.txt (line 2)) (1.2.1)
# Requirement already satisfied: posthog>=2.4.0 in ./new_env3.8/lib/python3.8/site-packages (from chromadb->-r requirements.txt (line 2)) (3.5.0)
# Requirement already satisfied: pypika>=0.48.9 in ./new_env3.8/lib/python3.8/site-packages (from chromadb->-r requirements.txt (line 2)) (0.48.9)
# Requirement already satisfied: graphlib-backport>=1.0.3 in ./new_env3.8/lib/python3.8/site-packages (from chromadb->-r requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in ./new_env3.8/lib/python3.8/site-packages (from chromadb->-r requirements.txt (line 2)) (1.26.0)
# Requirement already satisfied: tqdm>=4.65.0 in ./new_env3.8/lib/python3.8/site-packages (from chromadb->-r requirements.txt (line 2)) (4.66.5)
# Requirement already satisfied: onnxruntime>=1.14.1 in ./new_env3.8/lib/python3.8/site-packages (from chromadb->-r requirements.txt (line 2)) (1.19.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in ./new_env3.8/lib/python3.8/site-packages (from chromadb->-r requirements.txt (line 2)) (0.47b0)
# Requirement already satisfied: tokenizers>=0.13.2 in ./new_env3.8/lib/python3.8/site-packages (from chromadb->-r requirements.txt (line 2)) (0.19.1)
# Requirement already satisfied: mmh3>=4.0.1 in ./new_env3.8/lib/python3.8/site-packages (from chromadb->-r requirements.txt (line 2)) (4.1.0)
# Requirement already satisfied: httpx>=0.27.0 in ./new_env3.8/lib/python3.8/site-packages (from chromadb->-r requirements.txt (line 2)) (0.27.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in ./new_env3.8/lib/python3.8/site-packages (from chromadb->-r requirements.txt (line 2)) (1.26.0)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in ./new_env3.8/lib/python3.8/site-packages (from chromadb->-r requirements.txt (line 2)) (0.30.6)
# Requirement already satisfied: tenacity>=8.2.3 in ./new_env3.8/lib/python3.8/site-packages (from chromadb->-r requirements.txt (line 2)) (8.5.0)
# Requirement already satisfied: overrides>=7.3.1 in ./new_env3.8/lib/python3.8/site-packages (from chromadb->-r requirements.txt (line 2)) (7.7.0)
# Requirement already satisfied: importlib-resources in ./new_env3.8/lib/python3.8/site-packages (from chromadb->-r requirements.txt (line 2)) (6.4.3)
# Requirement already satisfied: fastapi>=0.95.2 in ./new_env3.8/lib/python3.8/site-packages (from chromadb->-r requirements.txt (line 2)) (0.112.1)
# Requirement already satisfied: numpy<2.0.0,>=1.22.5 in ./new_env3.8/lib/python3.8/site-packages (from chromadb->-r requirements.txt (line 2)) (1.24.4)
# Requirement already satisfied: typer>=0.9.0 in ./new_env3.8/lib/python3.8/site-packages (from chromadb->-r requirements.txt (line 2)) (0.12.4)
# Requirement already satisfied: orjson>=3.9.12 in ./new_env3.8/lib/python3.8/site-packages (from chromadb->-r requirements.txt (line 2)) (3.10.7)
# Requirement already satisfied: typing-extensions>=4.5.0 in ./new_env3.8/lib/python3.8/site-packages (from chromadb->-r requirements.txt (line 2)) (4.12.2)
# Requirement already satisfied: PyYAML>=6.0.0 in ./new_env3.8/lib/python3.8/site-packages (from chromadb->-r requirements.txt (line 2)) (6.0.2)
# Requirement already satisfied: bcrypt>=4.0.1 in ./new_env3.8/lib/python3.8/site-packages (from chromadb->-r requirements.txt (line 2)) (4.2.0)
# Requirement already satisfied: kubernetes>=28.1.0 in ./new_env3.8/lib/python3.8/site-packages (from chromadb->-r requirements.txt (line 2)) (30.1.0)
# Requirement already satisfied: pandas in ./new_env3.8/lib/python3.8/site-packages (from datasets->-r requirements.txt (line 3)) (2.0.3)
# Requirement already satisfied: huggingface-hub>=0.21.2 in ./new_env3.8/lib/python3.8/site-packages (from datasets->-r requirements.txt (line 3)) (0.24.6)
# Requirement already satisfied: multiprocess in ./new_env3.8/lib/python3.8/site-packages (from datasets->-r requirements.txt (line 3)) (0.70.16)
# Requirement already satisfied: aiohttp in ./new_env3.8/lib/python3.8/site-packages (from datasets->-r requirements.txt (line 3)) (3.10.5)
# Requirement already satisfied: fsspec[http]<=2024.6.1,>=2023.1.0 in ./new_env3.8/lib/python3.8/site-packages (from datasets->-r requirements.txt (line 3)) (2024.6.1)
# Requirement already satisfied: filelock in ./new_env3.8/lib/python3.8/site-packages (from datasets->-r requirements.txt (line 3)) (3.15.4)
# Requirement already satisfied: packaging in ./new_env3.8/lib/python3.8/site-packages (from datasets->-r requirements.txt (line 3)) (24.1)
# Requirement already satisfied: requests>=2.32.2 in ./new_env3.8/lib/python3.8/site-packages (from datasets->-r requirements.txt (line 3)) (2.32.3)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in ./new_env3.8/lib/python3.8/site-packages (from datasets->-r requirements.txt (line 3)) (0.3.8)
# Requirement already satisfied: pyarrow>=15.0.0 in ./new_env3.8/lib/python3.8/site-packages (from datasets->-r requirements.txt (line 3)) (17.0.0)
# Requirement already satisfied: xxhash in ./new_env3.8/lib/python3.8/site-packages (from datasets->-r requirements.txt (line 3)) (3.5.0)
# Requirement already satisfied: jinja2<4.0 in ./new_env3.8/lib/python3.8/site-packages (from gradio->-r requirements.txt (line 4)) (3.1.4)
# Requirement already satisfied: pydub in ./new_env3.8/lib/python3.8/site-packages (from gradio->-r requirements.txt (line 4)) (0.25.1)
# Requirement already satisfied: semantic-version~=2.0 in ./new_env3.8/lib/python3.8/site-packages (from gradio->-r requirements.txt (line 4)) (2.10.0)
# Requirement already satisfied: matplotlib~=3.0 in ./new_env3.8/lib/python3.8/site-packages (from gradio->-r requirements.txt (line 4)) (3.7.5)
# Requirement already satisfied: gradio-client==1.3.0 in ./new_env3.8/lib/python3.8/site-packages (from gradio->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: ffmpy in ./new_env3.8/lib/python3.8/site-packages (from gradio->-r requirements.txt (line 4)) (0.4.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in ./new_env3.8/lib/python3.8/site-packages (from gradio->-r requirements.txt (line 4)) (23.2.1)
# Requirement already satisfied: pillow<11.0,>=8.0 in ./new_env3.8/lib/python3.8/site-packages (from gradio->-r requirements.txt (line 4)) (10.4.0)
# Requirement already satisfied: tomlkit==0.12.0 in ./new_env3.8/lib/python3.8/site-packages (from gradio->-r requirements.txt (line 4)) (0.12.0)
# Requirement already satisfied: ruff>=0.2.2 in ./new_env3.8/lib/python3.8/site-packages (from gradio->-r requirements.txt (line 4)) (0.6.1)
# Requirement already satisfied: python-multipart>=0.0.9 in ./new_env3.8/lib/python3.8/site-packages (from gradio->-r requirements.txt (line 4)) (0.0.9)
# Requirement already satisfied: markupsafe~=2.0 in ./new_env3.8/lib/python3.8/site-packages (from gradio->-r requirements.txt (line 4)) (2.1.5)
# Requirement already satisfied: anyio<5.0,>=3.0 in ./new_env3.8/lib/python3.8/site-packages (from gradio->-r requirements.txt (line 4)) (4.4.0)
# Requirement already satisfied: websockets<13.0,>=10.0 in ./new_env3.8/lib/python3.8/site-packages (from gradio-client==1.3.0->gradio->-r requirements.txt (line 4)) (12.0)
# Requirement already satisfied: hpack<5,>=4.0 in ./new_env3.8/lib/python3.8/site-packages (from h2->-r requirements.txt (line 5)) (4.0.0)
# Requirement already satisfied: hyperframe<7,>=6.0 in ./new_env3.8/lib/python3.8/site-packages (from h2->-r requirements.txt (line 5)) (6.0.1)
# Requirement already satisfied: ipython>=7.23.1 in ./new_env3.8/lib/python3.8/site-packages (from ipykernel->-r requirements.txt (line 7)) (8.12.3)
# Requirement already satisfied: pyzmq>=24 in ./new_env3.8/lib/python3.8/site-packages (from ipykernel->-r requirements.txt (line 7)) (26.1.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./new_env3.8/lib/python3.8/site-packages (from ipykernel->-r requirements.txt (line 7)) (5.7.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./new_env3.8/lib/python3.8/site-packages (from ipykernel->-r requirements.txt (line 7)) (8.6.2)
# Requirement already satisfied: tornado>=6.1 in ./new_env3.8/lib/python3.8/site-packages (from ipykernel->-r requirements.txt (line 7)) (6.4.1)
# Requirement already satisfied: psutil in ./new_env3.8/lib/python3.8/site-packages (from ipykernel->-r requirements.txt (line 7)) (6.0.0)
# Requirement already satisfied: traitlets>=5.4.0 in ./new_env3.8/lib/python3.8/site-packages (from ipykernel->-r requirements.txt (line 7)) (5.14.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./new_env3.8/lib/python3.8/site-packages (from ipykernel->-r requirements.txt (line 7)) (0.1.7)
# Requirement already satisfied: comm>=0.1.1 in ./new_env3.8/lib/python3.8/site-packages (from ipykernel->-r requirements.txt (line 7)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in ./new_env3.8/lib/python3.8/site-packages (from ipykernel->-r requirements.txt (line 7)) (1.8.5)
# Requirement already satisfied: nest-asyncio in ./new_env3.8/lib/python3.8/site-packages (from ipykernel->-r requirements.txt (line 7)) (1.6.0)
# Requirement already satisfied: autocommand in ./new_env3.8/lib/python3.8/site-packages (from jaraco.text->-r requirements.txt (line 8)) (2.2.2)
# Requirement already satisfied: more-itertools in ./new_env3.8/lib/python3.8/site-packages (from jaraco.text->-r requirements.txt (line 8)) (10.4.0)
# Requirement already satisfied: jaraco.context>=4.1 in ./new_env3.8/lib/python3.8/site-packages (from jaraco.text->-r requirements.txt (line 8)) (6.0.1)
# Requirement already satisfied: jaraco.functools in ./new_env3.8/lib/python3.8/site-packages (from jaraco.text->-r requirements.txt (line 8)) (4.0.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in ./new_env3.8/lib/python3.8/site-packages (from langchain-community->-r requirements.txt (line 9)) (0.1.99)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./new_env3.8/lib/python3.8/site-packages (from langchain-community->-r requirements.txt (line 9)) (2.0.32)
# Requirement already satisfied: langchain<0.3.0,>=0.2.13 in ./new_env3.8/lib/python3.8/site-packages (from langchain-community->-r requirements.txt (line 9)) (0.2.14)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.30 in ./new_env3.8/lib/python3.8/site-packages (from langchain-community->-r requirements.txt (line 9)) (0.2.33)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in ./new_env3.8/lib/python3.8/site-packages (from langchain-community->-r requirements.txt (line 9)) (0.6.7)
# Requirement already satisfied: haystack-ai in ./new_env3.8/lib/python3.8/site-packages (from ollama-haystack->-r requirements.txt (line 10)) (2.4.0)
# Requirement already satisfied: annotated-types>=0.4.0 in ./new_env3.8/lib/python3.8/site-packages (from pydantic->-r requirements.txt (line 15)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in ./new_env3.8/lib/python3.8/site-packages (from pydantic->-r requirements.txt (line 15)) (2.20.1)
# Requirement already satisfied: qdrant-client>=1.10.0 in ./new_env3.8/lib/python3.8/site-packages (from qdrant-haystack->-r requirements.txt (line 17)) (1.11.0)
# Requirement already satisfied: scikit-learn in ./new_env3.8/lib/python3.8/site-packages (from sentence-transformers->-r requirements.txt (line 18)) (1.3.2)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in ./new_env3.8/lib/python3.8/site-packages (from sentence-transformers->-r requirements.txt (line 18)) (4.44.0)
# Requirement already satisfied: scipy in ./new_env3.8/lib/python3.8/site-packages (from sentence-transformers->-r requirements.txt (line 18)) (1.10.1)
# Requirement already satisfied: torch>=1.11.0 in ./new_env3.8/lib/python3.8/site-packages (from sentence-transformers->-r requirements.txt (line 18)) (2.4.0)
# Requirement already satisfied: attrs>=17.3.0 in ./new_env3.8/lib/python3.8/site-packages (from aiohttp->datasets->-r requirements.txt (line 3)) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./new_env3.8/lib/python3.8/site-packages (from aiohttp->datasets->-r requirements.txt (line 3)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./new_env3.8/lib/python3.8/site-packages (from aiohttp->datasets->-r requirements.txt (line 3)) (6.0.5)
# Requirement already satisfied: aiosignal>=1.1.2 in ./new_env3.8/lib/python3.8/site-packages (from aiohttp->datasets->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./new_env3.8/lib/python3.8/site-packages (from aiohttp->datasets->-r requirements.txt (line 3)) (1.9.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./new_env3.8/lib/python3.8/site-packages (from aiohttp->datasets->-r requirements.txt (line 3)) (2.4.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in ./new_env3.8/lib/python3.8/site-packages (from aiohttp->datasets->-r requirements.txt (line 3)) (4.0.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./new_env3.8/lib/python3.8/site-packages (from anyio<5.0,>=3.0->gradio->-r requirements.txt (line 4)) (1.2.2)
# Requirement already satisfied: idna>=2.8 in ./new_env3.8/lib/python3.8/site-packages (from anyio<5.0,>=3.0->gradio->-r requirements.txt (line 4)) (3.7)
# Requirement already satisfied: sniffio>=1.1 in ./new_env3.8/lib/python3.8/site-packages (from anyio<5.0,>=3.0->gradio->-r requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: pyproject_hooks in ./new_env3.8/lib/python3.8/site-packages (from build>=1.0.3->chromadb->-r requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: importlib-metadata>=4.6 in ./new_env3.8/lib/python3.8/site-packages (from build>=1.0.3->chromadb->-r requirements.txt (line 2)) (8.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./new_env3.8/lib/python3.8/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community->-r requirements.txt (line 9)) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./new_env3.8/lib/python3.8/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community->-r requirements.txt (line 9)) (0.9.0)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in ./new_env3.8/lib/python3.8/site-packages (from fastapi>=0.95.2->chromadb->-r requirements.txt (line 2)) (0.38.2)
# Requirement already satisfied: certifi in ./new_env3.8/lib/python3.8/site-packages (from httpx>=0.27.0->chromadb->-r requirements.txt (line 2)) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in ./new_env3.8/lib/python3.8/site-packages (from httpx>=0.27.0->chromadb->-r requirements.txt (line 2)) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in ./new_env3.8/lib/python3.8/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb->-r requirements.txt (line 2)) (0.14.0)
# Requirement already satisfied: zipp>=3.1.0 in ./new_env3.8/lib/python3.8/site-packages (from importlib-resources->chromadb->-r requirements.txt (line 2)) (3.20.0)
# Requirement already satisfied: pexpect>4.3 in ./new_env3.8/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 7)) (4.9.0)
# Requirement already satisfied: jedi>=0.16 in ./new_env3.8/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 7)) (0.19.1)
# Requirement already satisfied: backcall in ./new_env3.8/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: decorator in ./new_env3.8/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 7)) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in ./new_env3.8/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 7)) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in ./new_env3.8/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 7)) (2.18.0)
# Requirement already satisfied: pickleshare in ./new_env3.8/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 7)) (0.7.5)
# Requirement already satisfied: stack-data in ./new_env3.8/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 7)) (0.6.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./new_env3.8/lib/python3.8/site-packages (from jupyter-client>=6.1.12->ipykernel->-r requirements.txt (line 7)) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in ./new_env3.8/lib/python3.8/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->-r requirements.txt (line 7)) (4.2.2)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in ./new_env3.8/lib/python3.8/site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: google-auth>=1.0.1 in ./new_env3.8/lib/python3.8/site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 2)) (2.34.0)
# Requirement already satisfied: six>=1.9.0 in ./new_env3.8/lib/python3.8/site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: oauthlib>=3.2.2 in ./new_env3.8/lib/python3.8/site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 2)) (3.2.2)
# Requirement already satisfied: requests-oauthlib in ./new_env3.8/lib/python3.8/site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in ./new_env3.8/lib/python3.8/site-packages (from langchain<0.3.0,>=0.2.13->langchain-community->-r requirements.txt (line 9)) (0.2.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./new_env3.8/lib/python3.8/site-packages (from langchain-core<0.3.0,>=0.2.30->langchain-community->-r requirements.txt (line 9)) (1.33)
# Requirement already satisfied: contourpy>=1.0.1 in ./new_env3.8/lib/python3.8/site-packages (from matplotlib~=3.0->gradio->-r requirements.txt (line 4)) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in ./new_env3.8/lib/python3.8/site-packages (from matplotlib~=3.0->gradio->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in ./new_env3.8/lib/python3.8/site-packages (from matplotlib~=3.0->gradio->-r requirements.txt (line 4)) (3.1.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./new_env3.8/lib/python3.8/site-packages (from matplotlib~=3.0->gradio->-r requirements.txt (line 4)) (1.4.5)
# Requirement already satisfied: fonttools>=4.22.0 in ./new_env3.8/lib/python3.8/site-packages (from matplotlib~=3.0->gradio->-r requirements.txt (line 4)) (4.53.1)
# Requirement already satisfied: sympy in ./new_env3.8/lib/python3.8/site-packages (from onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 2)) (1.13.2)
# Requirement already satisfied: coloredlogs in ./new_env3.8/lib/python3.8/site-packages (from onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 2)) (15.0.1)
# Requirement already satisfied: protobuf in ./new_env3.8/lib/python3.8/site-packages (from onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 2)) (4.25.4)
# Requirement already satisfied: flatbuffers in ./new_env3.8/lib/python3.8/site-packages (from onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 2)) (24.3.25)
# Requirement already satisfied: deprecated>=1.2.6 in ./new_env3.8/lib/python3.8/site-packages (from opentelemetry-api>=1.2.0->chromadb->-r requirements.txt (line 2)) (1.2.14)
# Requirement already satisfied: opentelemetry-proto==1.26.0 in ./new_env3.8/lib/python3.8/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r requirements.txt (line 2)) (1.26.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.26.0 in ./new_env3.8/lib/python3.8/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r requirements.txt (line 2)) (1.26.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in ./new_env3.8/lib/python3.8/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r requirements.txt (line 2)) (1.63.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.47b0 in ./new_env3.8/lib/python3.8/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r requirements.txt (line 2)) (0.47b0)
# Requirement already satisfied: opentelemetry-util-http==0.47b0 in ./new_env3.8/lib/python3.8/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r requirements.txt (line 2)) (0.47b0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.47b0 in ./new_env3.8/lib/python3.8/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r requirements.txt (line 2)) (0.47b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.47b0 in ./new_env3.8/lib/python3.8/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r requirements.txt (line 2)) (0.47b0)
# Requirement already satisfied: setuptools>=16.0 in ./new_env3.8/lib/python3.8/site-packages (from opentelemetry-instrumentation==0.47b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r requirements.txt (line 2)) (56.0.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in ./new_env3.8/lib/python3.8/site-packages (from opentelemetry-instrumentation==0.47b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: asgiref~=3.0 in ./new_env3.8/lib/python3.8/site-packages (from opentelemetry-instrumentation-asgi==0.47b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r requirements.txt (line 2)) (3.8.1)
# Requirement already satisfied: pytz>=2020.1 in ./new_env3.8/lib/python3.8/site-packages (from pandas->datasets->-r requirements.txt (line 3)) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in ./new_env3.8/lib/python3.8/site-packages (from pandas->datasets->-r requirements.txt (line 3)) (2024.1)
# Requirement already satisfied: monotonic>=1.5 in ./new_env3.8/lib/python3.8/site-packages (from posthog>=2.4.0->chromadb->-r requirements.txt (line 2)) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in ./new_env3.8/lib/python3.8/site-packages (from posthog>=2.4.0->chromadb->-r requirements.txt (line 2)) (2.2.1)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in ./new_env3.8/lib/python3.8/site-packages (from qdrant-client>=1.10.0->qdrant-haystack->-r requirements.txt (line 17)) (2.10.1)
# Requirement already satisfied: grpcio-tools>=1.41.0 in ./new_env3.8/lib/python3.8/site-packages (from qdrant-client>=1.10.0->qdrant-haystack->-r requirements.txt (line 17)) (1.62.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./new_env3.8/lib/python3.8/site-packages (from requests>=2.32.2->datasets->-r requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: greenlet!=0.4.17 in ./new_env3.8/lib/python3.8/site-packages (from SQLAlchemy<3,>=1.4->langchain-community->-r requirements.txt (line 9)) (3.0.3)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./new_env3.8/lib/python3.8/site-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 18)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in ./new_env3.8/lib/python3.8/site-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 18)) (2.20.5)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./new_env3.8/lib/python3.8/site-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 18)) (12.1.3.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./new_env3.8/lib/python3.8/site-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 18)) (12.1.105)
# Requirement already satisfied: networkx in ./new_env3.8/lib/python3.8/site-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 18)) (3.1)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./new_env3.8/lib/python3.8/site-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 18)) (9.1.0.70)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./new_env3.8/lib/python3.8/site-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 18)) (10.3.2.106)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./new_env3.8/lib/python3.8/site-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 18)) (12.1.105)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./new_env3.8/lib/python3.8/site-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 18)) (12.1.105)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./new_env3.8/lib/python3.8/site-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 18)) (11.4.5.107)
# Requirement already satisfied: triton==3.0.0 in ./new_env3.8/lib/python3.8/site-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 18)) (3.0.0)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./new_env3.8/lib/python3.8/site-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 18)) (11.0.2.54)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./new_env3.8/lib/python3.8/site-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 18)) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./new_env3.8/lib/python3.8/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers->-r requirements.txt (line 18)) (12.6.20)
# Requirement already satisfied: regex!=2019.12.17 in ./new_env3.8/lib/python3.8/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers->-r requirements.txt (line 18)) (2024.7.24)
# Requirement already satisfied: safetensors>=0.4.1 in ./new_env3.8/lib/python3.8/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers->-r requirements.txt (line 18)) (0.4.4)
# Requirement already satisfied: rich>=10.11.0 in ./new_env3.8/lib/python3.8/site-packages (from typer>=0.9.0->chromadb->-r requirements.txt (line 2)) (13.7.1)
# Requirement already satisfied: click>=8.0.0 in ./new_env3.8/lib/python3.8/site-packages (from typer>=0.9.0->chromadb->-r requirements.txt (line 2)) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in ./new_env3.8/lib/python3.8/site-packages (from typer>=0.9.0->chromadb->-r requirements.txt (line 2)) (1.5.4)
# Requirement already satisfied: lazy-imports in ./new_env3.8/lib/python3.8/site-packages (from haystack-ai->ollama-haystack->-r requirements.txt (line 10)) (0.3.1)
# Requirement already satisfied: openai>=1.1.0 in ./new_env3.8/lib/python3.8/site-packages (from haystack-ai->ollama-haystack->-r requirements.txt (line 10)) (1.41.1)
# Requirement already satisfied: haystack-experimental in ./new_env3.8/lib/python3.8/site-packages (from haystack-ai->ollama-haystack->-r requirements.txt (line 10)) (0.1.1)
# Requirement already satisfied: joblib>=1.1.1 in ./new_env3.8/lib/python3.8/site-packages (from scikit-learn->sentence-transformers->-r requirements.txt (line 18)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./new_env3.8/lib/python3.8/site-packages (from scikit-learn->sentence-transformers->-r requirements.txt (line 18)) (3.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./new_env3.8/lib/python3.8/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r requirements.txt (line 2)) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./new_env3.8/lib/python3.8/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r requirements.txt (line 2)) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./new_env3.8/lib/python3.8/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r requirements.txt (line 2)) (5.5.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./new_env3.8/lib/python3.8/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r requirements.txt (line 7)) (0.8.4)
# Requirement already satisfied: jsonpointer>=1.9 in ./new_env3.8/lib/python3.8/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.30->langchain-community->-r requirements.txt (line 9)) (3.0.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./new_env3.8/lib/python3.8/site-packages (from openai>=1.1.0->haystack-ai->ollama-haystack->-r requirements.txt (line 10)) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./new_env3.8/lib/python3.8/site-packages (from openai>=1.1.0->haystack-ai->ollama-haystack->-r requirements.txt (line 10)) (0.5.0)
# Requirement already satisfied: ptyprocess>=0.5 in ./new_env3.8/lib/python3.8/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->-r requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: wcwidth in ./new_env3.8/lib/python3.8/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel->-r requirements.txt (line 7)) (0.2.13)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./new_env3.8/lib/python3.8/site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./new_env3.8/lib/python3.8/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community->-r requirements.txt (line 9)) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in ./new_env3.8/lib/python3.8/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 2)) (10.0)
# Requirement already satisfied: executing>=1.2.0 in ./new_env3.8/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 7)) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./new_env3.8/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 7)) (2.4.1)
# Requirement already satisfied: pure-eval in ./new_env3.8/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 7)) (0.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./new_env3.8/lib/python3.8/site-packages (from sympy->onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in ./new_env3.8/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in ./new_env3.8/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r requirements.txt (line 2)) (0.6.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
from haystack import Pipeline
from haystack.document_stores.types import DuplicatePolicy
from haystack.components.builders.prompt_builder import PromptBuilder
from haystack_integrations.components.generators.ollama import OllamaGenerator
from haystack_integrations.components.retrievers.qdrant import QdrantEmbeddingRetriever
from haystack_integrations.document_stores.qdrant import QdrantDocumentStore
from haystack.components.embedders import SentenceTransformersTextEmbedder, SentenceTransformersDocumentEmbedder
from haystack import Document

# Function to read text file
def read_text_file(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            return file.read()
    except FileNotFoundError:
        print(f"Error: The file {file_path} was not found. Please make sure the file exists and the path is correct.")
        return None
    except Exception as e:
        print(f"An error occurred while reading the file: {str(e)}")
        return None

# Read the text file
file_path = "1.PMAY-U 2.0 FAQ.txt"  # Assuming you've converted the .docx to .txt
document_content = read_text_file(file_path)

if document_content is None:
    print("Exiting due to file read error.")
    exit(1)

# Initialize QdrantDocumentStore
document_store = QdrantDocumentStore(
    url='http://localhost:6333',
    recreate_index=True,
    return_embedding=True,
    wait_result_from_api=True,
)

# Create a Document object
document = Document(content=document_content)

# Initialize and use SentenceTransformersDocumentEmbedder
document_embedder = SentenceTransformersDocumentEmbedder()
document_embedder.warm_up()
documents_with_embeddings = document_embedder.run([document])

# Write document to the document store
document_store.write_documents(documents_with_embeddings.get("documents"), policy=DuplicatePolicy.OVERWRITE)

# Initialize QdrantEmbeddingRetriever
retriever = QdrantEmbeddingRetriever(document_store=document_store)

# Define the prompt template
template = """
Given only the following information from the PMAY-U 2.0 FAQ document, answer the question.
Ignore your own knowledge.
Context:
{% for document in documents %}
 {{ document.content }}
{% endfor %}
Question: {{ query }}
"""

# Set up the pipeline
pipe = Pipeline()
pipe.add_component("text_embedder", SentenceTransformersTextEmbedder())
pipe.add_component("retriever", retriever)
pipe.add_component("prompt_builder", PromptBuilder(template=template))
pipe.add_component("llm", OllamaGenerator(model="llama3", url="http://localhost:6333/api/generate"))
pipe.connect("text_embedder.embedding", "retriever.query_embedding")
pipe.connect("retriever", "prompt_builder.documents")
pipe.connect("prompt_builder", "llm")
# Out:
# Batches: 100%|██████████| 1/1 [00:00<00:00, 12.99it/s]
# 100it [00:00, 15792.40it/s]
# <haystack.core.pipeline.pipeline.Pipeline object at 0x72af8f4a9760>
# 🚅 Components
#   - text_embedder: SentenceTransformersTextEmbedder
#   - retriever: QdrantEmbeddingRetriever
#   - prompt_builder: PromptBuilder
#   - llm: OllamaGenerator
# 🛤️ Connections
#   - text_embedder.embedding -> retriever.query_embedding (List[float])
#   - retriever.documents -> prompt_builder.documents (List[Document])
#   - prompt_builder.prompt -> llm.prompt (str)

# %%
pipe.add_component("llma", OllamaGenerator(model="llama3", url="http://localhost:6333/correct_endpoint"))

# %%
# Example query
query = "How Central Assistance will be released for Private Sector AHP Projects ?"
response = pipe.run({"prompt_builder": {"query": query}, "text_embedder": {"text": query}})
print(response["llm"]["replies"])
# Out:
# Batches: 100%|██████████| 1/1 [00:00<00:00, 59.39it/s]
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 # Example query
#       2 query = "How Central Assistance will be released for Private Sector AHP Projects ?"
# ----> 3 response = pipe.run({"prompt_builder": {"query": query}, "text_embedder": {"text": query}})
#       4 print(response["llm"]["replies"])
#
# File ~/Documents/ChatBot/Llama3/new_env3.8/lib/python3.8/site-packages/haystack/core/pipeline/pipeline.py:233, in Pipeline.run(self, data, debug, include_outputs_from)
#     230     msg = f"Maximum loops count ({self.max_loops_allowed}) exceeded for component '{name}'"
#     231     raise PipelineMaxLoops(msg)
# --> 233 res: Dict[str, Any] = self._run_component(name, components_inputs[name])
#     235 if name in include_outputs_from:
#     236     # Deepcopy the outputs to prevent downstream nodes from modifying them
#     237     # We don't care about loops - Always store the last output.
#     238     extra_outputs[name] = deepcopy(res)
#
# File ~/Documents/ChatBot/Llama3/new_env3.8/lib/python3.8/site-packages/haystack/core/pipeline/pipeline.py:67, in Pipeline._run_component(self, name, inputs)
#      65 span.set_content_tag("haystack.component.input", inputs)
#      66 logger.info("Running component {component_name}", component_name=name)
# ---> 67 res: Dict[str, Any] = instance.run(**inputs)
#      68 self.graph.nodes[name]["visits"] += 1
#      70 # After a Component that has variadic inputs is run, we need to reset the variadic inputs that were consumed
#
# File ~/Documents/ChatBot/Llama3/new_env3.8/lib/python3.8/site-packages/haystack_integrations/components/generators/ollama/generator.py:198, in OllamaGenerator.run(self, prompt, generation_kwargs)
#     195 response = requests.post(url=self.url, json=json_payload, timeout=self.timeout, stream=stream)
#     197 # throw error on unsuccessful response
# --> 198 response.raise_for_status()
#     200 if stream:
#     201     chunks: List[StreamingChunk] = self._handle_streaming_response(response)
#
# File ~/Documents/ChatBot/Llama3/new_env3.8/lib/python3.8/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1019     http_error_msg = (
#    1020         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1021     )
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: http://localhost:6333/api/generate
